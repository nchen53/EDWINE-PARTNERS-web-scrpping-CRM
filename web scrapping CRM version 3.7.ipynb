# %%
#https://console.command.kw.com/login

# %%
#https://console.command.kw.com/command

# %%
import selenium 
selenium.__version__
# Out:
# '4.1.0'

# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from webdriver_manager.chrome import ChromeDriverManager
import time
import pandas as pd

# %%
driver =webdriver.Chrome(ChromeDriverManager().install())
# Out:
# ====== WebDriver manager ======
# Current google-chrome version is 98.0.4758
# Get LATEST chromedriver version for 98.0.4758 google-chrome
# Trying to download new driver from https://chromedriver.storage.googleapis.com/98.0.4758.102/chromedriver_win32.zip
# Driver has been saved in cache [C:\Users\ASUS\.wdm\drivers\chromedriver\win32\98.0.4758.102]
# <ipython-input-3-01e213c4aff9>:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver =webdriver.Chrome(ChromeDriverManager().install())

# %%
url = "https://console.command.kw.com/login"
username = '***********************passoword1 = '***********************

# %%
driver.get(url)

# %%
#<input class="text-input text-input--large" name="username" id="username" placeholder="User Name">
#<input class="text-input text-input--large pr-5" name="password" type="password" id="password" placeholder="Password">
#<div class="password-input"><input class="text-input text-input--large pr-5" name="password" type="password" id="password" placeholder="Password"><span class="icon icon--show icon--small password-input__toggle"></span></div>

# %%
driver.find_element_by_id("username").send_keys(username)
# Out:
# <ipython-input-6-93ee88329cfe>:1: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   driver.find_element_by_id("username").send_keys(username)

# %% [markdown]
# --------------------
# ----------

# %%
names=driver.find_elements_by_xpath('//h4[@class="txt-h4 styles__agentName___13JFP"]')
#phones=driver.find_elements_by_xpath('//div[@class="d-flex justify-content-between"]')
# Out:
# <ipython-input-7-6c07118d9cd8>:1: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   names=driver.find_elements_by_xpath('//h4[@class="txt-h4 styles__agentName___13JFP"]')

# %%
num_names=len(names)
print("total_num= ",num_names)
for i in range(num_names):

    print(names[i].text)
# Out:
# total_num=  76
# Nicole McAlister George
# Timothy Scott Garland Jr.
# Anthony Brown
# Danny King
# Chelsea Carpenter
# Josh Courtright
# Demian Sarvey
# Christopher Craig
# Laurie Plyler
# Tammie Cartledge
# Denise Pettit
# Trent Corbin
# Mario Mitchell
# Nathan Moss
# Lauren Butler
# Adam Sellars
# Jamie Milam
# Kadrick Baker
# Matt Briggs
# Kristen Bernard
# Rebecca Cullen
# Jeanene Campbell
# Denise Pettit
# Jennifer Marshall
# Joni Plyler
# Christopher Jordan
# Joseph Santagata
# Christy Stone
# Stacey Sauls
# Jordan Keaton
# Laurie Plyler
# Glen Levine
# Jeffrey Graham
# Theresa Pavone
# Melanie Outlaw
# Zhengzheng Wiley
# Diana Cabrera Blanco
# Tricia Foster
# Vernon Jackson
# Barry Reeves
# Lisa Bass
# Michael Thomas
# Irene Crespo Gonzalez
# Tammie Cartledge
# Matt Briggs
# Lisa Archer
# Leigh LaRue
# Karen Scully
# Daniel Gardner
# Alex Krasnoff
# Thomas Elrod
# Micah Winn
# Jack Crayne
# Elin Brown
# Ann Yountz
# Mikael McDaniel
# Josh Kelly
# Kim Bigach
# Ginny Williams
# ...

# %%
for j in range(num_names):
    driver.find_elements_by_xpath('//span[@aria-label="open accordion"]')[j].click()
    time.sleep(0.1)
# Out:
# <ipython-input-12-822c65a0ed71>:2: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   driver.find_elements_by_xpath('//span[@aria-label="open accordion"]')[j].click()
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-12-822c65a0ed71> in <module>
#       1 for j in range(num_names):
# ----> 2     driver.find_elements_by_xpath('//span[@aria-label="open accordion"]')[j].click()
#       3     time.sleep(0.1)
#
# IndexError: list index out of range

# %%
for j in range(num_names):
    driver.find_elements_by_xpath('.//span[@aria-label="open accordion"]')[j].click()
    time.sleep(0.2)
# Out:
# <ipython-input-10-4fc6c6a9fe3e>:2: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   driver.find_elements_by_xpath('.//span[@aria-label="open accordion"]')[j].click()
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-10-4fc6c6a9fe3e> in <module>
#       1 for j in range(num_names):
# ----> 2     driver.find_elements_by_xpath('.//span[@aria-label="open accordion"]')[j].click()
#       3     time.sleep(0.2)
#
# IndexError: list index out of range

# %%
for j in range(num_names):
    driver.find_elements_by_xpath('*//span[@aria-label="open accordion"]')[j].click()
    time.sleep(0.1)
# Out:
# <ipython-input-11-1e2a876eefe6>:2: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   driver.find_elements_by_xpath('*//span[@aria-label="open accordion"]')[j].click()
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-11-1e2a876eefe6> in <module>
#       1 for j in range(num_names):
# ----> 2     driver.find_elements_by_xpath('*//span[@aria-label="open accordion"]')[j].click()
#       3     time.sleep(0.1)
#
# IndexError: list index out of range

# %%
name_1=[]
num_names=len(names)
for i in range(num_names):

    name_1.append(names[i].text)
name_1
# Out:
# ['Nicole McAlister George',
#  'Timothy Scott Garland Jr.',
#  'Anthony Brown',
#  'Danny King',
#  'Chelsea Carpenter',
#  'Josh Courtright',
#  'Demian Sarvey',
#  'Christopher Craig',
#  'Laurie Plyler',
#  'Tammie Cartledge',
#  'Denise Pettit',
#  'Trent Corbin',
#  'Mario Mitchell',
#  'Nathan Moss',
#  'Lauren Butler',
#  'Adam Sellars',
#  'Jamie Milam',
#  'Kadrick Baker',
#  'Matt Briggs',
#  'Kristen Bernard',
#  'Rebecca Cullen',
#  'Jeanene Campbell',
#  'Denise Pettit',
#  'Jennifer Marshall',
#  'Joni Plyler',
#  'Christopher Jordan',
#  'Joseph Santagata',
#  'Christy Stone',
#  'Stacey Sauls',
#  'Jordan Keaton',
#  'Laurie Plyler',
#  'Glen Levine',
#  'Jeffrey Graham',
#  'Theresa Pavone',
#  'Melanie Outlaw',
#  'Zhengzheng Wiley',
#  'Diana Cabrera Blanco',
#  'Tricia Foster',
#  'Vernon Jackson',
#  'Barry Reeves',
#  'Lisa Bass',
#  'Michael Thomas',
#  'Irene Crespo Gonzalez',
#  'Tammie Cartledge',
#  'Matt Briggs',
#  'Lisa Archer',
#  'Leigh LaRue',
# ...

# %%
phones1=driver.find_elements_by_xpath('//div[@class="d-flex justify-content-between"]')
# Out:
# <ipython-input-13-939454e7d05e>:1: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   phones1=driver.find_elements_by_xpath('//div[@class="d-flex justify-content-between"]')

# %%
num_phone=len(phones1)
for i in range(num_phone):
    if phones1[i].text.startswith(("Phone")):
        print(phones1[i].text)
# Out:
# Phone
# 757-287-3800
# Phone
# 803-960-7113
# Phone
# 803.722.1900
# Phone
# 703-261-5238
# Phone
# 229.347.1828
# Phone
# 803-662-0579
# Phone
# 803-664-2770
# Phone
# 803-404-0360
# Phone
# 803-403-6636
# Phone
# 803-262-4460
# Phone
# 704-930-9369
# Phone
# 803-614-5012
# Phone
# 803-707-0226
# Phone
# 803-772-5858
# Phone
# 706-868-3772
# Phone
# 803-262-4460
# Phone
# 862-268-0161
# Phone
# 706-244-1057
# Phone
# 843.737.6780
# Phone
# 803-361-8606
# Phone
# 803-262-9796
# Phone
# 803-270-3301
# Phone
# 843-530-8800
# Phone
# 843-795-7950
# Phone
# 803-391-5804
# Phone
# 803-295-8573
# Phone
# 803-270-4501
# Phone
# 803-383-4449

# %%
phone_1=[]
num_phone=len(phones1)
for i in range(num_phone):
    if phones1[i].text.startswith(("Phone")):

        phone_1.append(phones1[i].text)
len(phone_1)
# Out:
# 75

# %%
num_phone=len(phones1)
for j in range(num_phone):
    if phones1[j].text.startswith(("Email")):
        print(phones1[j].text)
# Out:
# Email
# alstephens72@gmail.com
# Email
# mike@thederrickteam.com
# Email
# shamirajones@kw.com
# Email
# owen@costelloandcohomes.com
# Email
# jared@jromerogroup.com
# Email
# larry@thekemmerlincompany.org
# Email
# palmettorealtor10@gmail.com
# Email
# orangeburghousehunter@gmail.com
# Email
# tammy.davis@kw.com
# Email
# ericacook@kw.com
# Email
# Erictucker@kw.com
# Email
# furseclasshomes@gmail.com
# Email
# miranda.mole@realtornut.com
# Email
# levineglent@gmail.com
# Email
# tedavis29@gmail.com
# Email
# LaKesha.Harley@kw.com
# Email
# FantasticSouthernHomes@gmail.com
# Email
# sarahlightner@kw.com
# Email
# ernest@dreammakeragent.com
# Email
# tonyaebrown@kw.com
# Email
# stephanielombardo@kw.com
# Email
# jayson.hinkson@kw.com
# Email
# drewsalazar@kw.com
# Email
# davefriedman@kw.com
# Email
# carlvrealtor@gmail.com
# Email
# calebsmith@kw.com
# Email
# billytakesyouhome@gmail.com
# Email
# thescgahometeam@gmail.com

# %%
email_1=[]
num_phone=len(phones1)
for j in range(num_phone):
    if phones1[j].text.startswith(("Email")):
        email_1.append(phones1[j].text)
len(email_1)
# Out:
# 76

# %%
print(len(name_1),len(phone_1),len(email_1))
# Out:
# 76 75 76

# %%
num_phone=len(phones1)
for j in range(1):
    if phones1[j].text.startswith(("Email")):
        email_1.append(phones1[j].text)

# %%
for j in range(3):
    if phones1[j].text.startswith(("Email")):
        phone_1.append(phones1[j].text)

# %%
print(len(name_1),len(phone_1),len(email_1))
# Out:
# 76 76 76

# %%
data={'name':name_1,'phone':phone_1,'email':email_1}
df=pd.DataFrame(data)
df
# Out:
#                          name                                 phone  \
# 0     Nicole McAlister George                   Phone\n704.964.8718
# 1   Timothy Scott Garland Jr.                   Phone\n803-325-9990
# 2               Anthony Brown                   Phone\n704-351-9413
# 3                  Danny King                   Phone\n704-608-8157
# 4           Chelsea Carpenter                   Phone\n803-835-2300
# ..                        ...                                   ...
# 71            Jennifer Buenau                   Phone\n704-906-1973
# 72             Melanie Wilson                   Phone\n803-810-5267
# 73               Tony Swainey                   Phone\n704-497-3365
# 74               Mike Morrell                   Phone\n704.964.8718
# 75    Nicole McAlister George  Email\nNicoleM@mypremierproperty.com
#
#                                    email
# 0   Email\nNicoleM@mypremierproperty.com
# 1    Email\ntimothy@timothygarlandre.com
# ...

# %%
df.to_csv('raw_data_8.csv')

# %%
with open('result.csv','a') as f:
    for i in range(num_names):
        f.write.row[2](names[i].text+"\n")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-87-a41379f047e3> in <module>
#       1 with open('result.csv','a') as f:
#       2     for i in range(num_names):
# ----> 3         f.write.row[2](names[i].text+"\n")
#
# AttributeError: 'builtin_function_or_method' object has no attribute 'row'

# %%
for j in range(num_names):
    driver.find_elements_by_xpath('//span[@aria-label="open accordion"]')[j].click()
    time.sleep(0.5)
# Out:
# <ipython-input-21-e7064ea2071f>:2: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   driver.find_elements_by_xpath('//span[@aria-label="open accordion"]')[j].click()
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-21-e7064ea2071f> in <module>
#       1 for j in range(num_names):
# ----> 2     driver.find_elements_by_xpath('//span[@aria-label="open accordion"]')[j].click()
#       3     time.sleep(0.5)
#
# IndexError: list index out of range

# %%
phones=driver.find_elements_by_xpath('//div[@class="d-flex justify-content-between"]')
# Out:
# <ipython-input-22-09bfa6377f5c>:1: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   phones=driver.find_elements_by_xpath('//div[@class="d-flex justify-content-between"]')

# %%
<h4 class="txt-h4 styles__agentName___13JFP">Rusty Johnson</h4>

# %%
num_names=len(names)
for i in range(num_names):

    print(names[i].text+" : "+phones[i].text)
    print("--------------")
    print("\n")
# Out:
# Shane McCormack : Phone
# 803-445-6968
# --------------
#
#
# Rozalyn Franklin : Email
# shanemrealty@gmail.com
# --------------
#
#
# Ashley Sain : Language(s) Spoken
# English, Spanish
# --------------
#
#
# Mark Mozingo : Closed Units in this Area
# 7
# --------------
#
#
# Samantha Taylor : Closed Units
# 11
# --------------
#
#
# Margaret Ganis : Listings Sold
# 7
# --------------
#
#
# Richard Pollard : Buy Sides
# 4
# --------------
#
#
# John Ryan : Sales volume / last 12m
# $2.1M
# --------------
#
#
# Sharer Dale : Average deal size
# $186.5K
# --------------
#
#
# Tandra Meade : Phone
# 803-227-6943
# --------------
#
#
# Rusty Johnson : Email
# rozalynfranklin@kw.com
# --------------
#
#
# Andrew Vu : Language(s) Spoken
# English
# --------------
#
#
# Stephanie Lombardo : Closed Units in this Area
# 6
# --------------
#
#
# Laurie Smith : Closed Units
# 25
# --------------
#
#
# Terrance Davis : Listings Sold
# 11
# --------------
#
#
# Andrew Lemmon : Buy Sides
# 14
# ...

# %%
num_names
# Out:
# 129

# %%
phones1=driver.find_elements_by_xpath('//div[@class="d-flex justify-content-between"]')
# Out:
# <ipython-input-45-939454e7d05e>:1: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   phones1=driver.find_elements_by_xpath('//div[@class="d-flex justify-content-between"]')

# %%
num_phone=len(phones1)
for i in range(num_phone):
    if phones1[i].text.startswith(("Phone")):
        print(phones1[i].text)
# Out:
# Phone
# 803-445-6968
# Phone
# 803-227-6943
# Phone
# 828-228-1670
# Phone
# 803-665-3333
# Phone
# 803.477.0474
# Phone
# 8032611506
# Phone
# 803-807-3927
# Phone
# 803-960-9271
# Phone
# 803-522-3648
# Phone
# 803-309-9785
# Phone
# 803-358-8188
# Phone
# 803-262-4460
# Phone
# 803-262-9796
# Phone
# 803-240-7927
# Phone
# 706-868-3772
# Phone
# 803-206-6775
# Phone
# 803-727-5582
# Phone
# 803-260-6555
# Phone
# 803-772-5858
# Phone
# 803-467-0718
# Phone
# 803-439-2654
# Phone
# 8035752832
# Phone
# 706-726-0888
# Phone
# 803-470-6025
# Phone
# 803-645-3946
# Phone
# 803-664-2770
# Phone
# 803-834-9571
# Phone
# 803-404-0360
# Phone
# 803-772-5858
# Phone
# 803-900-0015
# Phone
# 8035722109
# Phone
# 803-772-5858
# Phone
# 803-378-5151
# Phone
# 803-470-4568
# Phone
# 803-602-4109
# Phone
# 803-201-0904
# Phone
# 803-225-4679
# Phone
# 803-446-1768
# Phone
# 803-354-2060
# Phone
# 803-270-4501
# Phone
# 803-924-1157
# Phone
# 9127556606
# Phone
# 803-960-7113
# Phone
# ...

# %%
num_phone=len(phones1)
for j in range(num_phone):
    if phones1[j].text.startswith(("Email")):
        print(phones1[j].text)
# Out:
# Email
# shanemrealty@gmail.com
# Email
# rozalynfranklin@kw.com
# Email
# ashleysain@kw.com
# Email
# mark@markmozingo.com
# Email
# thecarolinarealestatetteam@gmail.com
# Email
# margaretganis@kw.com
# Email
# richardpollardproperties@gmail.com
# Email
# jryansc@gmail.com
# Email
# sharerdale@gmail.com
# Email
# buymeadehomes@gmail.com
# Email
# RJ@rustyjohnson.com
# Email
# andrew.vu@kw.com
# Email
# stephanielombardo@kw.com
# Email
# laurie.smith@kw.com
# Email
# tedavis29@gmail.com
# Email
# andrewlemmon@kw.com
# Email
# Joshstevenson@kw.com
# Email
# JackieGriffin.KW@gmail.com
# Email
# dscloutier96@gmail.com
# Email
# gabrielle.gillie@gmail.com
# Email
# keyonasquire.kw@gmail.com
# Email
# seniquagriffin@kw.com
# Email
# Jaysonwillsellit@gmail.com
# Email
# tonygreenwood@kw.com
# Email
# andreamayson@kw.com
# Email
# palmettorealtor10@gmail.com
# Email
# meghan.lane@kw.com
# Email
# orangeburghousehunter@gmail.com
# Email
# sarahmking2012@gmail.com
# Email
# ...

# %%
num_names=len(names)
for i in range(num_names):

    print(names[i].text+" : "+phones1[i].text)
    print("--------------")
    print("\n")
# Out:
# Shane McCormack : Phone
# 803-445-6968
# --------------
#
#
# Rozalyn Franklin : Email
# shanemrealty@gmail.com
# --------------
#
#
# Ashley Sain : Language(s) Spoken
# English, Spanish
# --------------
#
#
# Mark Mozingo : Closed Units in this Area
# 7
# --------------
#
#
# Samantha Taylor : Closed Units
# 11
# --------------
#
#
# Margaret Ganis : Listings Sold
# 7
# --------------
#
#
# Richard Pollard : Buy Sides
# 4
# --------------
#
#
# John Ryan : Sales volume / last 12m
# $2.1M
# --------------
#
#
# Sharer Dale : Average deal size
# $186.5K
# --------------
#
#
# Tandra Meade : Phone
# 803-227-6943
# --------------
#
#
# Rusty Johnson : Email
# rozalynfranklin@kw.com
# --------------
#
#
# Andrew Vu : Language(s) Spoken
# English
# --------------
#
#
# Stephanie Lombardo : Closed Units in this Area
# 6
# --------------
#
#
# Laurie Smith : Closed Units
# 25
# --------------
#
#
# Terrance Davis : Listings Sold
# 11
# --------------
#
#
# Andrew Lemmon : Buy Sides
# 14
# ...

# %%
//*[@id="__next"]/div[3]/div/div[2]/div/div/div/div[2]/div[3]/div/div[2]/div/div[1]/div/div/div[2]/div/div/div[1]/div[1]

# %%
phones=driver.find_elements_by_xpath('//div[@class="d-flex justify-content-between"]')
# Out:
# <ipython-input-30-c41ef1beb864>:1: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   phones=driver.find_elements_by_xpath('//div[@class="d-flex justify-content-between"]/p/p')

# %%
num_phones=len(phones)
for i in range(num_phones):
    print(phones[i].text)
# Out:
# Team
# Carolina Results Team
# Phone
# 803-575-0411
# Email
# jeff@jeffrileyteam.com
# Language(s) Spoken
# English
# Closed Units in this Area
# 48
# Closed Units
# 67
# Listings Sold
# 59
# Buy Sides
# 17
# Sales volume / last 12m
# $15.4M
# Average deal size
# $229.5K
# Team
# The Holton Team
# Phone
# 803-270-4501
# Email
# billytakesyouhome@gmail.com
# Language(s) Spoken
# English
# Closed Units in this Area
# 1
# Closed Units
# 57
# Listings Sold
# 17
# Buy Sides
# 40
# Sales volume / last 12m
# $12.0M
# Average deal size
# $211.5K
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-19-74e2cbd11421> in <module>
#       1 num_phones=len(phones)
#       2 for i in range(num_phones):
# ----> 3     print(phones[i].text)
#
# D:\anaconda3\lib\site-packages\selenium\webdriver\remote\webelement.py in text(self)
#      75     def text(self) -> str:
# ...

# %%
<span aria-label="open accordion" class="styles__accordion-control___2gZID mr-2 p-2 cursor-pointer fa caret fa-caret-right"></span>

# %%
driver.find_elements_by_xpath('//span[@aria-label="open accordion"]')[2].click()
# Out:
# <ipython-input-27-9f2da63739d1>:1: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   driver.find_elements_by_xpath('//span[@aria-label="open accordion"]')[2].click()

# %%
<span aria-label="open accordion" class="styles__accordion-control___2gZID mr-2 p-2 cursor-pointer fa caret fa-caret-right"></span>

# %%
loginrul = ('https://console.command.kw.com/login')
secure_url = ('https://console.command.kw.com/command')

payload = {
    'username': 'eoghayore'
    'password': 'saadafe'
}

with request.session() as s:
    s.post(loginrul, data=payload)
    r = s.get(secure_url)
    soup = BeautifulSoup(r.content, 'html.parser')
    print(soup.prettify())
